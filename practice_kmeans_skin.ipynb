# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("/content/skin_multiclass_logistic_regression_data.xlsx")

# %%
X = df.drop('Acne_Severity_Class', axis=1)

# %%
model = KMeans(n_clusters=2, random_state=42)

# %%
df['Cluster'] = model.fit_predict(X)

# %%
print(df.head())
# Out:
#    Age  Age_Group  Oil_Level  Water_Intake_L  Sleep_Hours  Stress_Level  \
# 0   20          1          7               6            8             8
# 1   20          1          4               1            8            10
# 2   17          0          8               9            4             9
# 3   21          1          5               6            8             2
# 4   22          1          7               3           10            10
#
#    Acne_Count  SPF_Usage  Skin_Stress_Score  Hydration_Sleep_Index  \
# 0           2          0                 56                     14
# 1           2          1                 40                      9
# 2          17          1                 72                     13
# 3          18          1                 10                     14
# 4          18          1                 70                     13
#
#    Acne_Severity_Class  Cluster
# 0                    0        0
# 1                    0        0
# 2                    2        0
# 3                    2        1
# 4                    2        0

# %%
print(df['Cluster'].value_counts())
# Out:
# Cluster
# 1    140
# 0     60
# Name: count, dtype: int64

# %%
sse = []

# %%
for k in range(1, 11):
    km = KMeans(n_clusters=k, random_state=42)
    km.fit(X_scaled)
    sse.append(km.inertia_)

# %%
plt.plot(range(1,11), sse, marker='o')
plt.xlabel("K Value")
plt.ylabel("SSE")
plt.title("Elbow Method")
plt.show()

# %%
from sklearn.metrics import silhouette_score

score = silhouette_score(X_scaled, df['Cluster'])

print("Silhouette Score:", score)
# Out:
# Silhouette Score: 0.10899649918119732
