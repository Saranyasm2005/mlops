# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !apt-get install p7zip-full -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# p7zip-full is already the newest version (16.02+dfsg-8).
# 0 upgraded, 0 newly installed, 0 to remove and 51 not upgraded.

# %%
!7z x "/content/drive/MyDrive/Gun detection.v1i.yolo26.zip" -o/content/ -y
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.00GHz (50653),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 329633092 bytes (315 MiB)
#
# Extracting archive: /content/drive/MyDrive/Gun detection.v1i.yolo26.zip
# --
# Path = /content/drive/MyDrive/Gun detection.v1i.yolo26.zip
# Type = zip
# Physical Size = 329633092
#
# Everything is Ok
#
# Files: 44429
# Size:       317915570
# Compressed: 329633092

# %%
# !ls /content
# Out:
# data.yaml  README.dataset.txt	sample_data  train  yolov8n.pt
# drive	   README.roboflow.txt	test	     valid

# %%
# !ls /content/valid
# Out:
# images	labels

# %%
# !ls /content/test
# Out:
# images	labels

# %%
# !ls /content/train
# Out:
# images	labels

# %%
# !cp yolov8n.pt yolo26n.pt

# %%
# !yolo train \
model=yolo26n.pt \
data=/content/data.yaml \
epochs=30 \
imgsz=640 \
batch=16 \
device=0
# Out:
# Ultralytics 8.4.56 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from google.colab import files
files.download('/content/runs/detect/train-2/weights/last.pt')

# %%
import glob
result = glob.glob('/content/runs/**/*.pt', recursive=True)
print(result)
# Out:
# ['/content/runs/detect/train-2/weights/last.pt', '/content/runs/detect/train-2/weights/best.pt']

# %%
import shutil
shutil.copy(
    '/content/runs/detect/train-2/weights/best.pt',
    '/content/drive/MyDrive/best.pt'
)
print("✅ Saved!")
# Out:
# ✅ Saved!

# %%
from google.colab import drive
drive.mount('/content/drive')

from ultralytics import YOLO
model = YOLO('/content/drive/MyDrive/best.pt')
print("✅ Model Loaded!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Model Loaded!

# %%
from google.colab import drive
drive.mount('/content/drive')

from ultralytics import YOLO
model = YOLO('/content/drive/MyDrive/best.pt')
print("✅ Model Ready!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Model Ready!

# %%
from google.colab import files
files.download('/content/runs/detect/train-2/weights/best.pt')

# %%
import shutil
shutil.copy(
    '/content/runs/detect/train-2/weights/best.pt',
    '/content/drive/MyDrive/best.pt'
)
print("✅ Saved!")
# Out:
# ✅ Saved!

# %%
from google.colab import files

files.download(
'/content/runs/detect/train-2/weights/best.pt'
)

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-b8ea4b7e-b1fc-4bc6-a268-759eec71f2ad" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b8ea4b7e-b1fc-4bc6-a268-759eec71f2ad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls /content
# Out:
#  data.yaml	       sample_data   yolov8n.pt
#  drive		       test	     yolov8n.pt.1
#  README.dataset.txt    train	    'YOUTUBE_YouTubeCCTV116_gun_1 (1).mp4'
#  README.roboflow.txt   valid	     YOUTUBE_YouTubeCCTV116_gun_1.mp4
#  runs		       yolo26n.pt

# %%
from ultralytics import YOLO

model = YOLO('/content/runs/detect/train-2/weights/best.pt')

results = model.predict(
    source='/content/YOUTUBE_YouTubeCCTV116_gun_1.mp4',
    conf=0.5,
    save=True
)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/60) /content/YOUTUBE_YouTubeCCTV116_gun_1.mp4: 384x640 (no detections), 6.8ms
# video 1/1 (frame 2/60) /content/YOUTUBE_YouTubeCCTV116_gun_1.mp4: 384x640 (no detections), 6.6ms
# video 1/1 (frame 3/60) /content/YOUTUBE_YouTubeCCTV116_gun_1.mp4: 384x640 (no detections), 7.0ms
# video 1/1 (frame 4/60) /content/YOUTUBE_YouTubeCCTV116_gun_1.mp4: 384x640 (no detections), 6.5ms
# ...

# %%
# !find /content/runs -iname "*.mp4"
# Out:
# predict  predict-2  train  train-2

# %%
# !ls /content
# Out:
# data.yaml	     sample_data  yolov8n.pt
# drive		     test	  yolov8n.pt.1
# README.dataset.txt   train	  YOUTUBE_YouTubeCCTV116_gun_1.mp4
# README.roboflow.txt  valid
# runs		     yolo26n.pt

# %%
# !find /content/runs -iname "*.mp4"

# %%
from google.colab import files

files.download('/content/drive/MyDrive/YOUTUBE_YouTubeCCTV116_gun_1.mp4')

# %%
# !ls /content/runs/detect
# Out:
# predict  predict-2  train  train-2

# %%
# !ls /content/runs/detect/predict
# Out:
# YOUTUBE_YouTubeCCTV116_gun_1.avi

# %%
from google.colab import files

files.download(
'/content/runs/detect/predict/YOUTUBE_YouTubeCCTV116_gun_1.avi'
)

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/best.pt')

metrics = model.val()

print(metrics)
# Out:
# Ultralytics 8.4.56 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 491.3±225.2 MB/s, size: 16.7 KB)
# val: Scanning /content/valid/labels.cache... 1851 images, 724 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1851/1851 194.1Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 116/116 8.1it/s 14.2s
#                    all       1851       1459      0.836       0.68       0.76       0.48
# Speed: 0.8ms preprocess, 2.9ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to /content/runs/detect/val
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7b4214cbd460>
# ...

# %%
print("mAP50 Accuracy:", metrics.box.map50 * 100)
# Out:
# mAP50 Accuracy: 76.01959352306588
